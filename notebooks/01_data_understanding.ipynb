# %%
import pandas as pd
from spotify_analysis.prep import clean_streaming_data

df = clean_streaming_data("../data/raw/spotify_history.csv")
df.head()

df.to_parquet("../data/processed/spotify_history_clean.parquet")

# %%
pd.read_parquet("../data/processed/spotify_history_clean.parquet").dtypes

# %%
print(spotify_data.isna().sum())

# %%
spotify_data['platform'].value_counts()

# %%
spotify_data['reason_start'].value_counts()

# %%
spotify_data['reason_end'].value_counts()

# %%
spotify_data['ms_played'].describe()

# %%
spotify_data.isnull().sum()

# %%
spotify_data['skipped'].value_counts(normalize=True)

# %%
print(pd.crosstab(spotify_data['reason_end'], spotify_data['skipped']))

# %%
print(spotify_data.groupby('skipped')['ms_played'].describe())

print(spotify_data.groupby('skipped')['reason_end'].describe())

# %%
import pandas as pd
print (pd.__version__)

# %%
import pandas as pd
spotify_data = pd.read_csv('../data/spotify_history.csv')

spotify_data.head()
# Out:
#         spotify_track_uri                   ts    platform  ms_played  \
# 0  2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34  web player       3185
# 1  1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37  web player      61865
# 2  487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24  web player     285386
# 3  5IyblF777jLZj1vGHG2UD3  2013-07-08 02:52:40  web player     134022
# 4  0GgAAB0ZMllFhbNc3mAodO  2013-07-08 03:17:52  web player          0
#
#                                       track_name        artist_name  \
# 0                            Say It, Just Say It       The Mowgli's
# 1  Drinking from the Bottle (feat. Tinie Tempah)      Calvin Harris
# 2                                    Born To Die       Lana Del Rey
# 3                               Off To The Races       Lana Del Rey
# 4                                      Half Mast  Empire Of The Sun
#
#                            album_name reason_start reason_end  shuffle  \
# ...

# %%
print(spotify_data.shape)

print(spotify_data.dtypes)

print(spotify_data.head().to_string())
# Out:
# (149860, 11)
# spotify_track_uri      str
# ts                     str
# platform               str
# ms_played            int64
# track_name             str
# artist_name            str
# album_name             str
# reason_start           str
# reason_end             str
# shuffle               bool
# skipped               bool
# dtype: object
#         spotify_track_uri                   ts    platform  ms_played                                     track_name        artist_name                          album_name reason_start reason_end  shuffle  skipped
# 0  2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34  web player       3185                            Say It, Just Say It       The Mowgli's                Waiting For The Dawn     autoplay   clickrow    False    False
# 1  1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37  web player      61865  Drinking from the Bottle (feat. Tinie Tempah)      Calvin Harris                           18 Months     clickrow   clickrow    False    False
# ...

# %%
print(spotify_data.isna().sum())
# Out:
# spotify_track_uri      0
# ts                     0
# platform               0
# ms_played              0
# track_name             0
# artist_name            0
# album_name             0
# reason_start         143
# reason_end           117
# shuffle                0
# skipped                0
# dtype: int64

# %%
spotify_data['ts'] = pd.to_datetime(spotify_data['ts'], format='%Y-%m-%d %H:%M:%S')

print(spotify_data.dtypes)

print(spotify_data['ts'].head())

print(spotify_data['ts'].min())
print(spotify_data['ts'].max())
# Out:
# spotify_track_uri               str
# ts                   datetime64[us]
# platform                        str
# ms_played                     int64
# track_name                      str
# artist_name                     str
# album_name                      str
# reason_start                    str
# reason_end                      str
# shuffle                        bool
# skipped                        bool
# dtype: object
# 0   2013-07-08 02:44:34
# 1   2013-07-08 02:45:37
# 2   2013-07-08 02:50:24
# 3   2013-07-08 02:52:40
# 4   2013-07-08 03:17:52
# Name: ts, dtype: datetime64[us]
# 2013-07-08 02:44:34
# 2024-12-15 23:06:25

# %%
spotify_data['platform'].value_counts()
# Out:
# platform
# android           139821
# cast to device      3898
# iOS                 3049
# windows             1691
# mac                 1176
# web player           225
# Name: count, dtype: int64

# %%
spotify_data['reason_start'].value_counts()
# Out:
# reason_start
# trackdone     76655
# fwdbtn        53793
# clickrow      11228
# appload        3729
# backbtn        2205
# playbtn        1458
# remote          477
# trackerror      120
# unknown          23
# nextbtn          21
# popup             5
# endplay           2
# autoplay          1
# Name: count, dtype: int64

# %%
spotify_data['reason_end'].value_counts()
# Out:
# reason_end
# trackdone                       77194
# fwdbtn                          53470
# endplay                         10119
# logout                           4367
# backbtn                          2182
# unexpected-exit-while-paused     1725
# unknown                           268
# remote                            224
# unexpected-exit                   118
# clickrow                           34
# nextbtn                            21
# appload                             7
# popup                               6
# reload                              4
# trackerror                          4
# Name: count, dtype: int64

# %%
spotify_data['ms_played'].describe()
# Out:
# count    1.498600e+05
# mean     1.283166e+05
# std      1.178401e+05
# min      0.000000e+00
# 25%      2.795000e+03
# 50%      1.388400e+05
# 75%      2.185070e+05
# max      1.561125e+06
# Name: ms_played, dtype: float64

# %%
spotify_data.isnull().sum()
# Out:
# spotify_track_uri      0
# ts                     0
# platform               0
# ms_played              0
# track_name             0
# artist_name            0
# album_name             0
# reason_start         143
# reason_end           117
# shuffle                0
# skipped                0
# dtype: int64

# %%
spotify_data['skipped'].value_counts(normalize=True)
# Out:
# skipped
# False    0.947491
# True     0.052509
# Name: proportion, dtype: float64

# %%
print(pd.crosstab(spotify_data['reason_end'], spotify_data['skipped']))
# Out:
# skipped                       False  True
# reason_end
# appload                           0      7
# backbtn                        1941    241
# clickrow                         30      4
# endplay                        8109   2010
# fwdbtn                        48019   5451
# logout                         4367      0
# nextbtn                          21      0
# popup                             0      6
# reload                            4      0
# remote                          224      0
# trackdone                     77172     22
# trackerror                        4      0
# unexpected-exit                 118      0
# unexpected-exit-while-paused   1725      0
# unknown                         252     16

# %%
print(spotify_data.groupby('skipped')['ms_played'].describe())

print(spotify_data.groupby('skipped')['reason_end'].describe())
# Out:
#             count           mean            std  min     25%       50%  \
# skipped
# False    141991.0  133688.500651  117827.260384  0.0  3223.0  148367.0
# True       7869.0   31384.806074   63440.822724  0.0  1532.0    3157.0
#
#               75%        max
# skipped
# False    221880.0  1561125.0
# True      24649.0  1142390.0
#           count unique        top   freq
# skipped
# False    141986     13  trackdone  77172
# True       7757      8     fwdbtn   5451

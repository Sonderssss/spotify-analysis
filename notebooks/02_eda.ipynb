# %%
import pandas as pd

spotify_data = pd.read_csv('../data/spotify_history.csv')

spotify_data.head()
# Out:
#         spotify_track_uri                   ts    platform  ms_played  \
# 0  2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34  web player       3185
# 1  1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37  web player      61865
# 2  487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24  web player     285386
# 3  5IyblF777jLZj1vGHG2UD3  2013-07-08 02:52:40  web player     134022
# 4  0GgAAB0ZMllFhbNc3mAodO  2013-07-08 03:17:52  web player          0
#
#                                       track_name        artist_name  \
# 0                            Say It, Just Say It       The Mowgli's
# 1  Drinking from the Bottle (feat. Tinie Tempah)      Calvin Harris
# 2                                    Born To Die       Lana Del Rey
# 3                               Off To The Races       Lana Del Rey
# 4                                      Half Mast  Empire Of The Sun
#
#                            album_name reason_start reason_end  shuffle  \
# 0                Waiting For The Dawn     autoplay   clickrow    False
# 1                           18 Months     clickrow   clickrow    False
# 2  Born To Die - The Paradise Edition     clickrow    unknown    False
# 3  Born To Die - The Paradise Edition    trackdone   clickrow    False
# 4                  Walking On A Dream     clickrow    nextbtn    False
#
#    skipped
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False

# %%
#creating year column
spotify_data['year'] = spotify_data['ts'].dt.year

#confirming
spotify_data.head()

#group by year and count the number of plays
spotify_data.groupby('year')['ms_played'].count()
# Out:
# year
# 2013      185
# 2014       23
# 2015     2809
# 2016     6413
# 2017    26320
# 2018    14817
# 2019    14927
# 2020    24280
# 2021    22991
# 2022    16202
# 2023    11023
# 2024     9870
# Name: ms_played, dtype: int64

# %%
spotify_data.groupby('year')['ms_played'].sum()
# Out:
# year
# 2013      28188473
# 2014       3741827
# 2015     213294973
# 2016     711442358
# 2017    2414317674
# 2018    1707224590
# 2019    1724978591
# 2020    3314351885
# 2021    3210333331
# 2022    2309688236
# 2023    1854229109
# 2024    1737739888
# Name: ms_played, dtype: int64

# %%
spotify_data.groupby('year')['ms_played'].sum() / spotify_data.groupby('year')['ms_played'].count()
# Out:
# year
# 2013    152370.124324
# 2014    162688.130435
# 2015     75932.706657
# 2016    110937.526587
# 2017     91729.394909
# 2018    115220.664777
# 2019    115560.969451
# 2020    136505.431837
# 2021    139634.349572
# 2022    142555.748426
# 2023    168214.561281
# 2024    176062.805268
# Name: ms_played, dtype: float64

# %%
spotify_data['month'] = spotify_data['ts'].dt.month

spotify_data.head()

spotify_data.groupby('month')['ms_played'].count()
# Out:
# month
# 1     12525
# 2      8465
# 3      9378
# 4     12204
# 5     10068
# 6     10680
# 7     11619
# 8     15737
# 9     17733
# 10    16388
# 11    13230
# 12    11833
# Name: ms_played, dtype: int64

# %%
spotify_data.groupby('month')['ms_played'].sum()
# Out:
# month
# 1     1526799478
# 2     1300957014
# 3     1483519716
# 4     1605020568
# 5     1302369189
# 6     1567538851
# 7     1404187844
# 8     1826510613
# 9     1927342293
# 10    2001885143
# 11    1745638722
# 12    1537761504
# Name: ms_played, dtype: int64

# %%
spotify_data['hour'] = spotify_data['ts'].dt.hour

spotify_data.head()

spotify_data.groupby('hour')['ms_played'].count()
# Out:
# hour
# 0     10884
# 1      9395
# 2      9029
# 3      8550
# 4      6355
# 5      7164
# 6      7369
# 7      4412
# 8      2312
# 9      1695
# 10     1207
# 11      903
# 12      724
# 13     1658
# 14     2759
# 15     3725
# 16     6737
# 17     9194
# 18     8945
# 19     8165
# 20    10494
# 21     8953
# 22     8715
# 23    10516
# Name: ms_played, dtype: int64

# %%
spotify_data['day_of_week'] = spotify_data['ts'].dt.day_name()

spotify_data.head()
# Out:
#         spotify_track_uri                  ts    platform  ms_played  \
# 0  2J3n32GeLmMjwuAzyhcSNe 2013-07-08 02:44:34  web player       3185
# 1  1oHxIPqJyvAYHy0PVrDU98 2013-07-08 02:45:37  web player      61865
# 2  487OPlneJNni3NWC8SYqhW 2013-07-08 02:50:24  web player     285386
# 3  5IyblF777jLZj1vGHG2UD3 2013-07-08 02:52:40  web player     134022
# 4  0GgAAB0ZMllFhbNc3mAodO 2013-07-08 03:17:52  web player          0
#
#                                       track_name        artist_name  \
# 0                            Say It, Just Say It       The Mowgli's
# 1  Drinking from the Bottle (feat. Tinie Tempah)      Calvin Harris
# 2                                    Born To Die       Lana Del Rey
# 3                               Off To The Races       Lana Del Rey
# 4                                      Half Mast  Empire Of The Sun
#
#                            album_name reason_start reason_end  shuffle  \
# 0                Waiting For The Dawn     autoplay   clickrow    False
# 1                           18 Months     clickrow   clickrow    False
# 2  Born To Die - The Paradise Edition     clickrow    unknown    False
# 3  Born To Die - The Paradise Edition    trackdone   clickrow    False
# 4                  Walking On A Dream     clickrow    nextbtn    False
#
#    skipped  year  month  hour day_of_week
# 0    False  2013      7     2      Monday
# 1    False  2013      7     2      Monday
# 2    False  2013      7     2      Monday
# 3    False  2013      7     2      Monday
# 4    False  2013      7     3      Monday

# %%
spotify_data.groupby('day_of_week')['ms_played'].count()
# Out:
# day_of_week
# Friday       25646
# Monday       21031
# Saturday     19397
# Sunday       18274
# Thursday     21401
# Tuesday      20705
# Wednesday    23406
# Name: ms_played, dtype: int64

# %%
spotify_data.groupby('day_of_week')['ms_played'].sum()
# Out:
# day_of_week
# Friday       3179886000
# Monday       2756606773
# Saturday     2342416834
# Sunday       2357452184
# Thursday     2856250659
# Tuesday      2789060780
# Wednesday    2947857705
# Name: ms_played, dtype: int64

# %%
spotify_data['ts_localized'] = spotify_data['ts'].dt.tz_localize('UTC').dt.tz_convert('Africa/Nairobi').dt.tz_localize(None)

spotify_data.head()
# Out:
#         spotify_track_uri                  ts    platform  ms_played  \
# 0  2J3n32GeLmMjwuAzyhcSNe 2013-07-08 02:44:34  web player       3185
# 1  1oHxIPqJyvAYHy0PVrDU98 2013-07-08 02:45:37  web player      61865
# 2  487OPlneJNni3NWC8SYqhW 2013-07-08 02:50:24  web player     285386
# 3  5IyblF777jLZj1vGHG2UD3 2013-07-08 02:52:40  web player     134022
# 4  0GgAAB0ZMllFhbNc3mAodO 2013-07-08 03:17:52  web player          0
#
#                                       track_name        artist_name  \
# 0                            Say It, Just Say It       The Mowgli's
# 1  Drinking from the Bottle (feat. Tinie Tempah)      Calvin Harris
# 2                                    Born To Die       Lana Del Rey
# 3                               Off To The Races       Lana Del Rey
# 4                                      Half Mast  Empire Of The Sun
#
#                            album_name reason_start reason_end  shuffle  \
# 0                Waiting For The Dawn     autoplay   clickrow    False
# 1                           18 Months     clickrow   clickrow    False
# 2  Born To Die - The Paradise Edition     clickrow    unknown    False
# 3  Born To Die - The Paradise Edition    trackdone   clickrow    False
# 4                  Walking On A Dream     clickrow    nextbtn    False
#
#    skipped  year  month  hour day_of_week        ts_localized
# 0    False  2013      7     2      Monday 2013-07-08 05:44:34
# 1    False  2013      7     2      Monday 2013-07-08 05:45:37
# 2    False  2013      7     2      Monday 2013-07-08 05:50:24
# 3    False  2013      7     2      Monday 2013-07-08 05:52:40
# 4    False  2013      7     3      Monday 2013-07-08 06:17:52

# %%
spotify_data['localized_hour'] = spotify_data['ts_localized'].dt.hour

spotify_data.groupby('localized_hour')['ms_played'].count()
# Out:
# localized_hour
# 0      8953
# 1      8715
# 2     10516
# 3     10884
# 4      9395
# 5      9029
# 6      8550
# 7      6355
# 8      7164
# 9      7369
# 10     4412
# 11     2312
# 12     1695
# 13     1207
# 14      903
# 15      724
# 16     1658
# 17     2759
# 18     3725
# 19     6737
# 20     9194
# 21     8945
# 22     8165
# 23    10494
# Name: ms_played, dtype: int64

# %%
spotify_data.groupby('localized_hour')['ms_played'].sum()
# Out:
# localized_hour
# 0     1103120343
# 1     1010028440
# 2     1238240387
# 3     1312203073
# 4     1152781434
# 5     1042453971
# 6      995115661
# 7      843056241
# 8      823795162
# 9      806886094
# 10     510276198
# 11     302125757
# 12     208856355
# 13     149635971
# 14     106475849
# 15     105299849
# 16     228272369
# 17     408869071
# 18     563763786
# 19     984231663
# 20    1381863288
# 21    1383650073
# 22    1268453764
# 23    1300076136
# Name: ms_played, dtype: int64

# %%
#EDA on top artists songs and albums

# %%
#EDA on top artists

spotify_data['artist_name'].value_counts().head(20)
# Out:
# artist_name
# The Beatles               13621
# The Killers                6878
# John Mayer                 4855
# Bob Dylan                  3814
# Paul McCartney             2697
# Led Zeppelin               2482
# Johnny Cash                2478
# The Rolling Stones         2390
# Radiohead                  2305
# The Black Keys             2231
# Imagine Dragons            2116
# Pink Floyd                 2105
# The Strokes                1818
# Coldplay                   1631
# Arctic Monkeys             1600
# Lou Reed                   1558
# The Velvet Underground     1507
# Ed Sheeran                 1458
# Howard Shore               1446
# Kings of Leon              1381
# Name: count, dtype: int64

# %%
#EDA on top songs 
spotify_data.groupby('artist_name')['ms_played'].sum().sort_values(ascending=False).head(20)
# Out:
# artist_name
# The Beatles           1210184552
# The Killers           1059556516
# John Mayer             725219443
# Bob Dylan              569456396
# Paul McCartney         357354370
# Howard Shore           348930675
# The Strokes            317508419
# The Rolling Stones     307917009
# Pink Floyd             260531842
# Led Zeppelin           248338279
# Imagine Dragons        242372149
# Johnny Cash            239690064
# Kings of Leon          218527911
# Radiohead              216657418
# Coldplay               207509023
# Joaquín Sabina         196264369
# The Black Keys         192035798
# Billy Joel             179524974
# Arctic Monkeys         179431742
# Mumford & Sons         161529624
# Name: ms_played, dtype: int64

# %%
avg_m= spotify_data.groupby('artist_name')['ms_played'].sum() / spotify_data['artist_name'].value_counts()
# Out:
# artist_name
# Cory Weeds                 661773.000000
# Dan Lacksman               645080.500000
# Dave Matthews Band         641926.000000
# Mike Oldfield              619951.166667
# Brad Mehldau               600533.000000
# George Martin              569613.000000
# Azymuth                    568180.000000
# Mudcrutch                  568093.000000
# Robe                       550626.000000
# Les Ya Toupas Du Zaire     536586.000000
# Molly Hatchet              486598.000000
# Peter Cat Recording Co.    483840.000000
# Musica Relajante           481906.000000
# Rolf Kühn                  476992.000000
# Bud Powell Trio            461938.500000
# Benis Cletin               456866.000000
# Hidden Orchestra           450591.000000
# The Funkees                448914.000000
# Neverdogs                  448000.000000
# Rosey Chan                 448000.000000
# dtype: float64

# %%
artist_summary = spotify_data.groupby('artist_name')['ms_played'].agg(['mean','count'])

print(artist_summary[artist_summary['count'] > 10].sort_values(by='mean', ascending=False).head(20))
# Out:
#                            mean  count
# artist_name
# Miles Davis       332386.928571     14
# Polo & Pan        311427.600000     15
# Charanga 76       300205.470588     17
# Vincenzo Bellini  288968.830986     71
# Ajate             281932.727273     11
# Peach Pit         279958.944444     36
# Pulp              269204.839080     87
# Ludovico Einaudi  266180.250000     28
# Chuck Prophet     265579.500000     16
# Kasabian          265406.040000     25
# Lennie Niehaus    260767.020690    145
# Bee Gees          260033.818182     11
# El Chicano        257647.882353     17
# Rawayana          252338.000000     27
# ACHKIRIK          251946.117647     17
# Funkadelic        249981.450980     51
# Jamiroquai        247289.937500     16
# Joaquín Sabina    246563.277638    796
# CLUBZ             245186.800000     15
# B.B. King         244082.905172    116

# %%
# Most Played Tracks
spotify_data['track_name'].value_counts().head(20)
# Out:
# track_name
# Ode To The Mets                      207
# In the Blood                         181
# Dying Breed                          166
# Caution                              164
# 19 Dias y 500 Noches - En Directo    148
# For What It's Worth                  146
# All These Things That I've Done      142
# Concerning Hobbits                   142
# Come Together - Remastered 2009      137
# The Boxer                            135
# Yesterday - Remastered 2009          134
# Crucify Your Mind                    131
# Mr. Brightside                       128
# Reminder                             128
# Cavalleria rusticana: Intermezzo     128
# Sweet Virginia                       127
# I Guess I Just Feel Like             127
# Nuovo Cinema Paradiso                127
# Imploding The Mirage                 123
# Claudia's Theme - Version Eight      123
# Name: count, dtype: int64

# %%
spotify_data.groupby(['track_name','artist_name'])['ms_played'].sum().sort_values(ascending=False).head(20)
# Out:
# track_name                                                                           artist_name
# Ode To The Mets                                                                      The Strokes           67431580
# The Return of the King (feat. Sir James Galway, Viggo Mortensen and Renee Fleming)   Howard Shore          64401661
# The Fellowship Reunited (feat. Sir James Galway, Viggo Mortensen and Renée Fleming)  Howard Shore          44756730
# 19 Dias y 500 Noches - En Directo                                                    Joaquín Sabina        42914042
# In the Blood                                                                         John Mayer            38427087
# Claudia's Theme - Version Eight                                                      Lennie Niehaus        37120900
# Dying Breed                                                                          The Killers           36182653
# The Breaking of the Fellowship (feat. "In Dreams")                                   Howard Shore          35990898
# All These Things That I've Done                                                      The Killers           35754915
# Caution                                                                              The Killers           35619945
# The Road Goes Ever On..., Pt. 1                                                      Howard Shore          35236377
# Epilogue                                                                             Justin Hurwitz        32659024
# I Guess I Just Feel Like                                                             John Mayer            29948904
# The Journey to the Grey Havens (feat. Sir James Galway)                              Howard Shore          29461194
# Visions of Johanna                                                                   Bob Dylan             29152119
# 100,000 People                                                                       Kings of Leon         28335506
# Imploding The Mirage                                                                 The Killers           28034163
# Lily, Rosemary and the Jack of Hearts                                                Bob Dylan             27858015
# Did My Best                                                                          The Voidz             27814602
# Sweet Virginia                                                                       The Rolling Stones    27685640
# Name: ms_played, dtype: int64
